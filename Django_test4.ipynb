# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Web /Django/Test/Test 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/Web /Django/Test/Test 4

# %%
# !ls
# Out:
#  Django_test4.ipynb
#  project4
# ' vnotes  django signup signin page demo video.webm'
# '@@@@@@@@@@ vnotes django signup signin page demo video.webm'

# %%
# !pip install django
# Out:
# Collecting django
#   Downloading Django-3.2.9-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 5.0 MB/s
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django) (2018.9)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django) (0.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django) (3.10.0.2)
# Installing collected packages: asgiref, django
# Successfully installed asgiref-3.4.1 django-3.2.9

# %%
# !django-admin startproject project4

# %%
# !ls
# Out:
#  Django_test4.ipynb
#  project4
# ' vnotes  django signup signin page demo video.webm'
# '@@@@@@@@@@ vnotes django signup signin page demo video.webm'

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://a4y0hdh9s4w-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# %cd project4/
# Out:
# /content/drive/My Drive/Colab Notebooks/Web /Django/Test/Test 4/project4

# %%
# !ls
# Out:
# app1  db.sqlite3  manage.py  project4  tamplates

# %%
# !python manage.py runserver 8000
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 18 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): admin, auth, contenttypes, sessions.
# Run 'python manage.py migrate' to apply them.
# November 18, 2021 - 11:49:29
# Django version 3.2.9, using settings 'project4.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [18/Nov/2021 11:49:31] "GET / HTTP/1.1" 200 513
# Not Found: /favicon.ico
# [18/Nov/2021 11:49:33] "GET /favicon.ico HTTP/1.1" 404 2619
# [18/Nov/2021 11:49:36] "GET /signup HTTP/1.1" 200 1915
# Not Found: /favicon.ico
# [18/Nov/2021 11:49:37] "GET /favicon.ico HTTP/1.1" 404 2619

# %%
# !python manage.py startapp app1
# Out:
# CommandError: 'app1' conflicts with the name of an existing Python module and cannot be used as an app name. Please try another name.
